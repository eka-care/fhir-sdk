# %%
import sys
sys.path.append("../")

"""
Complete Example - Demonstrates all FHIR SDK features.

This example mimics a real prescription pad scenario with all fields.
"""

import json
from datetime import datetime, timedelta

from fhir_sdk import (
    FHIRDocumentBuilder,
    DosageBuilder,
    Severity,
    Laterality,
    FindingStatus,
    ConditionClinicalStatus,
    MedicationStatementStatus,
    RouteOfAdministration,
    EventTiming,
    Interpretation,
    AllergyCategory,
    AllergyCriticality,
)


def main():
    # Create a new document builder
    builder = FHIRDocumentBuilder()
    
    # =========================================================================
    # PATIENT INFORMATION
    # =========================================================================
    builder.add_patient(
        name="Rahul Sharma",
        age=(30, "years"),
        gender="male",
        identifiers=[
            ("ABHA-1234567890", "ABHA"),
            ("MRN-001234", "MRN"),
            ("9876543210", "mobile")
        ],
        address="123 Main Street, Koramangala, Bangalore, Karnataka 560034",
        phone="9876543210",
        email="rahul.sharma@email.com"
    )
    
    # =========================================================================
    # ENCOUNTER INFORMATION
    # =========================================================================
    builder.add_encounter(
        encounter_class="ambulatory",
        encounter_type="Consultation",
        facility_name="Apollo Hospital",
        department="General Medicine",
        period_start=datetime.now()
    )
    
    # =========================================================================
    # SYMPTOMS (Chief Complaints)
    # =========================================================================
    builder.add_symptom(
        code="Headache",
        severity=Severity.MODERATE,
        laterality=Laterality.RIGHT,
        onset=datetime.now() - timedelta(days=1),
        notes="Higher in the morning and decreases towards the evening",
        finding_status=FindingStatus.PRESENT
    )
    
    builder.add_symptom(
        code="Leg pain",
        finding_status=FindingStatus.ABSENT  # Negative finding
    )
    
    # =========================================================================
    # DIAGNOSIS (Encounter Diagnoses)
    # =========================================================================
    builder.add_medical_condition_encountered(
        code="Type 2 diabetes",
        severity=Severity.MILD,
        onset=datetime.now() - timedelta(days=3)
    )
    
    builder.add_medical_condition_encountered(
        code="Cardiac condition",
        severity=Severity.MILD,
        laterality=Laterality.LEFT,
        notes="On the left portion"
    )
    
    # =========================================================================
    # VITALS
    # =========================================================================
    builder.add_vital_finding(
        code="Blood Pressure",
        value="120/80",
        unit="mmHg",
        interpretation=Interpretation.NORMAL
    )
    
    # =========================================================================
    # LAB FINDINGS (Lab Vitals)
    # =========================================================================
    builder.add_lab_finding(
        code="Hemoglobin",
        value=12,
        unit="percent",
        interpretation=Interpretation.NORMAL
    )
    
    builder.add_lab_finding(
        code="PCM test",
        interpretation=Interpretation.NORMAL
    )
    
    # =========================================================================
    # MEDICAL HISTORY
    # =========================================================================
    
    # Past Medical Conditions
    builder.add_medical_condition_history(
        code="Hypertension",
        clinical_status=ConditionClinicalStatus.ACTIVE,
        onset="2020-01-01",
        notes="Very severe"
    )
    
    # Current Medications (History)
    builder.add_medication_history(
        medication="Crocin 600",
        status=MedicationStatementStatus.ACTIVE,
        effective_start=datetime.now() - timedelta(days=90),
        notes="Every week once"
    )
    
    # Family History
    builder.add_family_history(
        condition="Hypertension",
        relation="Father",
        onset="1997",
        status="completed"
    )
    
    builder.add_family_history(
        condition="Type 2 diabetes",
        relation="Mother",
        status="completed",
        deceased=True,
        notes="Mother is dead now"
    )
    
    # Lifestyle Habits
    builder.add_lifestyle_history(
        code="Smoking",
        status_value="Active"
    )
    
    builder.add_lifestyle_history(
        code="Drinking",
        status_value="Active",
        notes="Occasional drinker"
    )
    
    # Recent Travel History
    builder.add_lifestyle_history(
        code="Traveled to Singapore",
        status_value="Active",
        notes="Came back a couple of weeks ago"
    )
    
    # Allergies
    builder.add_allergy_history(
        code="Pollen allergy",
        category=AllergyCategory.ENVIRONMENT
    )
    
    builder.add_allergy_history(
        code="Paracetamol",
        category=AllergyCategory.MEDICATION
    )
    
    # Past Procedures
    builder.add_procedure_history(
        code="Vasectomy",
        status="completed"
    )
    
    # Vaccination History
    builder.add_immunisation_history(
        vaccine="COVID vaccine",
        notes="Done during the second wave of COVID"
    )
    
    # Examinations
    builder.add_examination_finding(
        code="Hand examination",
        value="Swollen"
    )
    
    # =========================================================================
    # LAB TESTS ORDERED
    # =========================================================================
    builder.add_test_prescribed(
        code="CBC test"
    )
    
    builder.add_test_prescribed(
        code="Fasting blood sugar test",
        notes="Should be done on empty stomach"
    )
    
    # =========================================================================
    # MEDICATIONS PRESCRIBED
    # =========================================================================
    builder.add_medication_prescribed(
        medication="Dolo 650 Tablet",
        dosage=DosageBuilder.build(
            dose_value=1,
            dose_unit="tablet",
            frequency=3,
            period=1,
            period_unit="d",
            route=RouteOfAdministration.ORAL,
            timing_code=EventTiming.AFTER_MEAL,
            text="Take 1 tablet three times daily after meals"
        ),
        duration_value=7,
        duration_unit="d",
        notes="Dose: 1 tablet"
    )
    
    # =========================================================================
    # FOLLOW-UP
    # =========================================================================
    builder.add_followup(
        date="2025-05-21",
        notes="Come with empty stomach"
    )
    
    # =========================================================================
    # ADVICE
    # =========================================================================
    builder.add_advice(note="Drink plenty of water")
    builder.add_advice(note="Do not go out in sun")
    builder.add_advice(note="Do not eat oily food")
    
    # =========================================================================
    # PRESCRIPTION NOTES
    # =========================================================================
    builder.add_notes(
        note="Patient is a 30 year old living in Bangalore",
        category="prescription-note"
    )

    # =========================================================================
    # CONVERT TO FHIR
    # =========================================================================
    fhir_bundle = builder.convert_to_fhir()

    print("=" * 80)
    print("COMPLETE FHIR BUNDLE OUTPUT")
    print("=" * 80)
    print(json.dumps(fhir_bundle, indent=2))

    # Summary
    bundle_obj = builder.get_bundle()
    print(f"\n{'=' * 80}")
    print("BUNDLE SUMMARY")
    print("=" * 80)
    print(f"Total entries: {len(bundle_obj.entry or [])}")
#     print("\nResources by type:")

#     resource_counts = {}
#     for entry in bundle_obj.entry or []:
#         resource_type = entry.resource.resource_type
#         resource_counts[resource_type] = resource_counts.get(resource_type, 0) + 1

#     for resource_type, count in sorted(resource_counts.items()):
#         print(f"  - {resource_type}: {count}")

# %%
main()
# Out:
# ================================================================================
# COMPLETE FHIR BUNDLE OUTPUT
# ================================================================================
# {
#   "resourceType": "Bundle",
#   "id": "49b4ee3e-6ecc-4433-8da6-8a69ed10f059",
#   "type": "collection",
#   "timestamp": "2026-01-15T13:20:06.050818Z",
#   "entry": [
#     {
#       "fullUrl": "urn:uuid:9d953d04-1d59-4cca-b026-6d285b27b69b",
#       "resource": {
#         "resourceType": "Patient",
#         "id": "9d953d04-1d59-4cca-b026-6d285b27b69b",
#         "identifier": [
#           {
#             "type": {
#               "coding": [
#                 {
#                   "system": "http://nrces.in/ndhm/fhir/r4/CodeSystem/ndhm-identifier-type-code",
#                   "code": "ABHA",
#                   "display": "ABHA"
#                 }
#               ]
#             },
#             "value": "ABHA-1234567890"
#           },
#           {
#             "type": {
#               "coding": [
#                 {
#                   "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#                   "code": "MR",
#                   "display": "MR"
#                 }
#               ]
#             },
#             "value": "MRN-001234"
#           },
#           {
#             "type": {
#               "coding": [
#                 {
#                   "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#                   "code": "PHONE",
#                   "display": "PHONE"
#                 }
#               ]
#             },
#             "value": "9876543210"
#           }
#         ],
#         "name": [
#           {
#             "text": "Rahul Sharma",
#             "family": "Sharma",
#             "given": [
#               "Rahul"
#             ]
#           }
#         ],
#         "telecom": [
#           {
#             "system": "phone",
#             "value": "9876543210",
#             "use": "mobile"
#           },
#           {
#             "system": "email",
#             "value": "rahul.sharma@email.com"
#           }
#         ],
#         "gender": "male",
#         "birthDate": "1996-01-15",
#         "address": [
#           {
#             "text": "123 Main Street, Koramangala, Bangalore, Karnataka 560034",
#             "line": [
#               "123 Main Street, Koramangala, Bangalore, Karnataka 560034"
#             ]
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:32ee7b36-f70f-473e-b76e-a40faa60ae10",
#       "resource": {
#         "resourceType": "Encounter",
#         "id": "32ee7b36-f70f-473e-b76e-a40faa60ae10",
#         "status": "finished",
#         "class": [
#           {
#             "coding": [
#               {
#                 "system": "http://terminology.hl7.org/CodeSystem/v3-ActCode",
#                 "code": "AMB",
#                 "display": "ambulatory"
#               }
#             ]
#           }
#         ],
#         "type": [
#           {
#             "coding": [
#               {
#                 "system": "http://terminology.hl7.org/CodeSystem/encounter-type",
#                 "code": "consultation",
#                 "display": "Consultation"
#               }
#             ],
#             "text": "Consultation"
#           }
#         ],
#         "serviceType": [
#           {
#             "concept": {
#               "text": "General Medicine"
#             }
#           }
#         ],
#         "subject": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "serviceProvider": {
#           "display": "Apollo Hospital"
#         },
#         "actualPeriod": {
#           "start": "2026-01-15T18:50:06.034999+05:30"
#         }
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:aea2a17f-72a8-4f5d-9327-4628cfb4caa7",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "aea2a17f-72a8-4f5d-9327-4628cfb4caa7",
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://terminology.hl7.org/CodeSystem/observation-category",
#                 "code": "symptom",
#                 "display": "Symptom"
#               }
#             ],
#             "text": "symptom"
#           }
#         ],
#         "code": {
#           "text": "Headache"
#         },
#         "subject": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         },
#         "effectiveDateTime": "2026-01-14T18:50:06.036050+05:30",
#         "note": [
#           {
#             "text": "Higher in the morning and decreases towards the evening"
#           }
#         ],
#         "component": [
#           {
#             "code": {
#               "coding": [
#                 {
#                   "system": "http://snomed.info/sct",
#                   "code": "246112005",
#                   "display": "Severity"
#                 }
#               ]
#             },
#             "valueCodeableConcept": {
#               "coding": [
#                 {
#                   "system": "http://snomed.info/sct",
#                   "code": "6736007",
#                   "display": "Moderate"
#                 }
#               ],
#               "text": "Moderate"
#             }
#           },
#           {
#             "code": {
#               "coding": [
#                 {
#                   "system": "http://snomed.info/sct",
#                   "code": "272741003",
#                   "display": "Laterality"
#                 }
#               ]
#             },
#             "valueCodeableConcept": {
#               "coding": [
#                 {
#                   "system": "http://snomed.info/sct",
#                   "code": "24028007",
#                   "display": "Right"
#                 }
#               ],
#               "text": "Right"
#             }
#           },
#           {
#             "code": {
#               "coding": [
#                 {
#                   "system": "http://snomed.info/sct",
#                   "code": "408729009",
#                   "display": "Finding context"
#                 }
#               ]
#             },
#             "valueCodeableConcept": {
#               "text": "Present"
#             }
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:7b455d8c-30e5-4944-b444-6dd847e92aa6",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "7b455d8c-30e5-4944-b444-6dd847e92aa6",
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://terminology.hl7.org/CodeSystem/observation-category",
#                 "code": "symptom",
#                 "display": "Symptom"
#               }
#             ],
#             "text": "symptom"
#           }
#         ],
#         "code": {
#           "text": "Leg pain"
#         },
#         "subject": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         },
#         "component": [
#           {
#             "code": {
#               "coding": [
#                 {
#                   "system": "http://snomed.info/sct",
#                   "code": "408729009",
#                   "display": "Finding context"
#                 }
#               ]
#             },
#             "valueCodeableConcept": {
#               "text": "Absent"
#             }
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:92fe7756-b2df-4854-9439-6d4de15892cd",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "92fe7756-b2df-4854-9439-6d4de15892cd",
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://terminology.hl7.org/CodeSystem/observation-category",
#                 "code": "vital-signs",
#                 "display": "Vital Signs"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "text": "Blood Pressure"
#         },
#         "subject": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         },
#         "valueString": "120/80",
#         "interpretation": [
#           {
#             "coding": [
#               {
#                 "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationInterpretation",
#                 "code": "N",
#                 "display": "Normal"
#               }
#             ],
#             "text": "Normal"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:ac9e9031-c116-4692-a748-1bfc94bcea64",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "ac9e9031-c116-4692-a748-1bfc94bcea64",
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://terminology.hl7.org/CodeSystem/observation-category",
#                 "code": "laboratory",
#                 "display": "Laboratory"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "text": "Hemoglobin"
#         },
#         "subject": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         },
#         "valueQuantity": {
#           "value": 12.0,
#           "unit": "percent",
#           "system": "http://unitsofmeasure.org",
#           "code": "percent"
#         },
#         "interpretation": [
#           {
#             "coding": [
#               {
#                 "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationInterpretation",
#                 "code": "N",
#                 "display": "Normal"
#               }
#             ],
#             "text": "Normal"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:e37122f1-d563-46c4-a534-a3fc211986f9",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "e37122f1-d563-46c4-a534-a3fc211986f9",
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://terminology.hl7.org/CodeSystem/observation-category",
#                 "code": "laboratory",
#                 "display": "Laboratory"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "text": "PCM test"
#         },
#         "subject": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         },
#         "interpretation": [
#           {
#             "coding": [
#               {
#                 "system": "http://terminology.hl7.org/CodeSystem/v3-ObservationInterpretation",
#                 "code": "N",
#                 "display": "Normal"
#               }
#             ],
#             "text": "Normal"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:75e73114-b159-41a4-8bb5-fc66f55e7d76",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "75e73114-b159-41a4-8bb5-fc66f55e7d76",
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://terminology.hl7.org/CodeSystem/observation-category",
#                 "code": "social-history",
#                 "display": "Social History"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "text": "Smoking"
#         },
#         "subject": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         },
#         "valueString": "Active"
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:1d219182-dfcf-4e37-9823-3f2d157c8803",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "1d219182-dfcf-4e37-9823-3f2d157c8803",
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://terminology.hl7.org/CodeSystem/observation-category",
#                 "code": "social-history",
#                 "display": "Social History"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "text": "Drinking"
#         },
#         "subject": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         },
#         "valueString": "Active",
#         "note": [
#           {
#             "text": "Occasional drinker"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:310133cf-c965-4652-8c3c-6e94b35a5a74",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "310133cf-c965-4652-8c3c-6e94b35a5a74",
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://terminology.hl7.org/CodeSystem/observation-category",
#                 "code": "social-history",
#                 "display": "Social History"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "text": "Traveled to Singapore"
#         },
#         "subject": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         },
#         "valueString": "Active",
#         "note": [
#           {
#             "text": "Came back a couple of weeks ago"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:5025b2ed-2f2c-4800-bd69-c90c799e1fb7",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "5025b2ed-2f2c-4800-bd69-c90c799e1fb7",
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://terminology.hl7.org/CodeSystem/observation-category",
#                 "code": "exam",
#                 "display": "Exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "text": "Hand examination"
#         },
#         "subject": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         },
#         "valueString": "Swollen"
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:f9135f41-d1a6-408c-9840-5faa4920bbab",
#       "resource": {
#         "resourceType": "Condition",
#         "id": "f9135f41-d1a6-408c-9840-5faa4920bbab",
#         "clinicalStatus": {
#           "coding": [
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#               "code": "active",
#               "display": "Active"
#             }
#           ]
#         },
#         "verificationStatus": {
#           "coding": [
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#               "code": "confirmed",
#               "display": "Confirmed"
#             }
#           ]
#         },
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://terminology.hl7.org/CodeSystem/condition-category",
#                 "code": "encounter-diagnosis",
#                 "display": "Encounter Diagnosis"
#               }
#             ]
#           }
#         ],
#         "severity": {
#           "coding": [
#             {
#               "system": "http://snomed.info/sct",
#               "code": "255604002",
#               "display": "Mild"
#             }
#           ],
#           "text": "Mild"
#         },
#         "code": {
#           "text": "Type 2 diabetes"
#         },
#         "subject": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         },
#         "onsetDateTime": "2026-01-12T18:50:06.037342+05:30"
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:46bd6d0f-2d25-41b2-a563-2c2bfa422e0e",
#       "resource": {
#         "resourceType": "Condition",
#         "id": "46bd6d0f-2d25-41b2-a563-2c2bfa422e0e",
#         "clinicalStatus": {
#           "coding": [
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#               "code": "active",
#               "display": "Active"
#             }
#           ]
#         },
#         "verificationStatus": {
#           "coding": [
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#               "code": "confirmed",
#               "display": "Confirmed"
#             }
#           ]
#         },
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://terminology.hl7.org/CodeSystem/condition-category",
#                 "code": "encounter-diagnosis",
#                 "display": "Encounter Diagnosis"
#               }
#             ]
#           }
#         ],
#         "severity": {
#           "coding": [
#             {
#               "system": "http://snomed.info/sct",
#               "code": "255604002",
#               "display": "Mild"
#             }
#           ],
#           "text": "Mild"
#         },
#         "code": {
#           "text": "Cardiac condition"
#         },
#         "bodySite": [
#           {
#             "coding": [
#               {
#                 "system": "http://snomed.info/sct",
#                 "code": "7771000",
#                 "display": "Left"
#               }
#             ],
#             "text": "Left"
#           }
#         ],
#         "subject": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         },
#         "note": [
#           {
#             "text": "On the left portion"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:11324cc4-cf36-4e72-991d-42a47ee20954",
#       "resource": {
#         "resourceType": "Condition",
#         "id": "11324cc4-cf36-4e72-991d-42a47ee20954",
#         "clinicalStatus": {
#           "coding": [
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#               "code": "active",
#               "display": "Active"
#             }
#           ]
#         },
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://terminology.hl7.org/CodeSystem/condition-category",
#                 "code": "problem-list-item",
#                 "display": "Problem List Item"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "text": "Hypertension"
#         },
#         "subject": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         },
#         "onsetDateTime": "2020-01-01",
#         "note": [
#           {
#             "text": "Very severe"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:e1cb10dd-7c71-481b-9823-4cc8a823afe8",
#       "resource": {
#         "resourceType": "MedicationRequest",
#         "id": "e1cb10dd-7c71-481b-9823-4cc8a823afe8",
#         "status": "active",
#         "intent": "order",
#         "medication": {
#           "concept": {
#             "text": "Dolo 650 Tablet"
#           }
#         },
#         "subject": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         },
#         "note": [
#           {
#             "text": "Dose: 1 tablet"
#           }
#         ],
#         "dosageInstruction": [
#           {
#             "text": "Take 1 tablet three times daily after meals",
#             "timing": {
#               "repeat": {
#                 "frequency": 3,
#                 "period": 1.0,
#                 "periodUnit": "d",
#                 "when": [
#                   "PC"
#                 ]
#               }
#             },
#             "asNeeded": false,
#             "route": {
#               "coding": [
#                 {
#                   "system": "http://snomed.info/sct",
#                   "code": "26643006",
#                   "display": "Oral"
#                 }
#               ],
#               "text": "Oral"
#             },
#             "doseAndRate": [
#               {
#                 "doseQuantity": {
#                   "value": 1.0,
#                   "unit": "tablet",
#                   "system": "http://unitsofmeasure.org",
#                   "code": "tablet"
#                 }
#               }
#             ]
#           }
#         ],
#         "dispenseRequest": {
#           "expectedSupplyDuration": {
#             "value": 7.0,
#             "unit": "d",
#             "system": "http://unitsofmeasure.org",
#             "code": "d"
#           }
#         }
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:a00c0592-02b5-4091-8842-b753f166aa2e",
#       "resource": {
#         "resourceType": "MedicationStatement",
#         "id": "a00c0592-02b5-4091-8842-b753f166aa2e",
#         "status": "active",
#         "medication": {
#           "concept": {
#             "text": "Crocin 600"
#           }
#         },
#         "subject": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "effectiveDateTime": "2025-10-17T18:50:06.040433+05:30",
#         "note": [
#           {
#             "text": "Every week once"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:d36da63e-6670-437c-9933-793c73c78132",
#       "resource": {
#         "resourceType": "ServiceRequest",
#         "id": "d36da63e-6670-437c-9933-793c73c78132",
#         "status": "active",
#         "intent": "order",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://snomed.info/sct",
#                 "code": "108252007",
#                 "display": "Laboratory procedure"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "concept": {
#             "text": "CBC test"
#           }
#         },
#         "subject": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         }
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:2447e2be-6bd0-44e6-9b90-9e81e290a7ae",
#       "resource": {
#         "resourceType": "ServiceRequest",
#         "id": "2447e2be-6bd0-44e6-9b90-9e81e290a7ae",
#         "status": "active",
#         "intent": "order",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://snomed.info/sct",
#                 "code": "108252007",
#                 "display": "Laboratory procedure"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "concept": {
#             "text": "Fasting blood sugar test"
#           }
#         },
#         "subject": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         },
#         "note": [
#           {
#             "text": "Should be done on empty stomach"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:523db48a-33e0-4e45-943e-4ecc0481d533",
#       "resource": {
#         "resourceType": "Procedure",
#         "id": "523db48a-33e0-4e45-943e-4ecc0481d533",
#         "status": "completed",
#         "code": {
#           "text": "Vasectomy"
#         },
#         "subject": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         }
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:777ca87c-be57-4db4-a3d2-dbc08e781f82",
#       "resource": {
#         "resourceType": "FamilyMemberHistory",
#         "id": "777ca87c-be57-4db4-a3d2-dbc08e781f82",
#         "status": "completed",
#         "patient": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "relationship": {
#           "coding": [
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-RoleCode",
#               "code": "FTH",
#               "display": "father"
#             }
#           ],
#           "text": "father"
#         },
#         "condition": [
#           {
#             "code": {
#               "text": "Hypertension"
#             },
#             "onsetString": "1997"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:e5a4c8e2-0525-4cc2-bdee-4dc0a36d60cf",
#       "resource": {
#         "resourceType": "FamilyMemberHistory",
#         "id": "e5a4c8e2-0525-4cc2-bdee-4dc0a36d60cf",
#         "status": "completed",
#         "patient": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "relationship": {
#           "coding": [
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-RoleCode",
#               "code": "MTH",
#               "display": "mother"
#             }
#           ],
#           "text": "mother"
#         },
#         "deceasedBoolean": true,
#         "note": [
#           {
#             "text": "Mother is dead now"
#           }
#         ],
#         "condition": [
#           {
#             "code": {
#               "text": "Type 2 diabetes"
#             },
#             "note": [
#               {
#                 "text": "Mother is dead now"
#               }
#             ]
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:c15232e5-fede-4704-93e2-685442f63832",
#       "resource": {
#         "resourceType": "AllergyIntolerance",
#         "id": "c15232e5-fede-4704-93e2-685442f63832",
#         "clinicalStatus": {
#           "coding": [
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/allergyintolerance-clinical",
#               "code": "active",
#               "display": "Active"
#             }
#           ]
#         },
#         "category": [
#           "environment"
#         ],
#         "code": {
#           "text": "Pollen allergy"
#         },
#         "patient": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         }
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:e0502b14-40fb-4214-a4ad-69da83edbd25",
#       "resource": {
#         "resourceType": "AllergyIntolerance",
#         "id": "e0502b14-40fb-4214-a4ad-69da83edbd25",
#         "clinicalStatus": {
#           "coding": [
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/allergyintolerance-clinical",
#               "code": "active",
#               "display": "Active"
#             }
#           ]
#         },
#         "category": [
#           "medication"
#         ],
#         "code": {
#           "text": "Paracetamol"
#         },
#         "patient": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         }
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:d7398cde-11fb-438a-b33a-1803655a0700",
#       "resource": {
#         "resourceType": "Immunization",
#         "id": "d7398cde-11fb-438a-b33a-1803655a0700",
#         "status": "completed",
#         "vaccineCode": {
#           "text": "COVID vaccine"
#         },
#         "patient": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         },
#         "occurrenceString": "Unknown",
#         "note": [
#           {
#             "text": "Done during the second wave of COVID"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:4554f945-8e3d-4760-872b-0b7a54ceeaae",
#       "resource": {
#         "resourceType": "Appointment",
#         "id": "4554f945-8e3d-4760-872b-0b7a54ceeaae",
#         "status": "booked",
#         "serviceType": [
#           {
#             "concept": {
#               "text": "Follow-up"
#             }
#           }
#         ],
#         "start": "2025-05-21T00:00:00",
#         "note": [
#           {
#             "text": "Come with empty stomach"
#           }
#         ],
#         "participant": [
#           {
#             "actor": {
#               "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#               "display": "Rahul Sharma"
#             },
#             "status": "accepted"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:fd7dd93c-6a30-4325-a187-eb911f14697d",
#       "resource": {
#         "resourceType": "CarePlan",
#         "id": "fd7dd93c-6a30-4325-a187-eb911f14697d",
#         "status": "active",
#         "intent": "plan",
#         "description": "Drink plenty of water",
#         "subject": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         },
#         "activity": [
#           {
#             "progress": [
#               {
#                 "text": "Drink plenty of water"
#               }
#             ]
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:0d7e367d-d531-4fda-8d04-ef6c34c7446f",
#       "resource": {
#         "resourceType": "CarePlan",
#         "id": "0d7e367d-d531-4fda-8d04-ef6c34c7446f",
#         "status": "active",
#         "intent": "plan",
#         "description": "Do not go out in sun",
#         "subject": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         },
#         "activity": [
#           {
#             "progress": [
#               {
#                 "text": "Do not go out in sun"
#               }
#             ]
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:6b0a5d66-85f9-4c06-83f4-0203c2deef22",
#       "resource": {
#         "resourceType": "CarePlan",
#         "id": "6b0a5d66-85f9-4c06-83f4-0203c2deef22",
#         "status": "active",
#         "intent": "plan",
#         "description": "Do not eat oily food",
#         "subject": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         },
#         "activity": [
#           {
#             "progress": [
#               {
#                 "text": "Do not eat oily food"
#               }
#             ]
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "urn:uuid:53a92136-e932-487a-9951-f0268985473b",
#       "resource": {
#         "resourceType": "Communication",
#         "id": "53a92136-e932-487a-9951-f0268985473b",
#         "status": "completed",
#         "category": [
#           {
#             "text": "prescription-note"
#           }
#         ],
#         "subject": {
#           "reference": "Patient/9d953d04-1d59-4cca-b026-6d285b27b69b",
#           "display": "Rahul Sharma"
#         },
#         "encounter": {
#           "reference": "Encounter/32ee7b36-f70f-473e-b76e-a40faa60ae10"
#         },
#         "payload": [
#           {
#             "contentCodeableConcept": {
#               "text": "Patient is a 30 year old living in Bangalore"
#             }
#           }
#         ]
#       }
#     }
#   ]
# }
#
# ================================================================================
# BUNDLE SUMMARY
# ================================================================================
# Total entries: 29

# %%
builder = FHIRDocumentBuilder()

# %%
builder.add_symptom(("headache")).json()
# Out:
# '{"resourceType":"Observation","id":"11da6ba1-e49d-4894-8194-492ede5b273b","status":"final","category":[{"coding":[{"system":"http://terminology.hl7.org/CodeSystem/observation-category","code":"survey","display":"Survey"}],"text":"Survey"}],"code":{"text":"headache"}}'

# %%
RouteOfAdministration.
# Out:
# <enum 'RouteOfAdministration'>

# %%
builder.add_test_prescribed(
        code="CBC test"
    ).json()
# Out:
# '{"resourceType":"ServiceRequest","id":"d05a1f3a-2bf4-48c0-86ac-4f98be3e8ac6","status":"active","intent":"order","category":[{"coding":[{"system":"http://snomed.info/sct","code":"108252007","display":"Laboratory procedure"}]}],"code":{"concept":{"text":"CBC test"}}}'

# %%
builder.add_medication_prescribed(
        medication="Dolo 650 Tablet",
        dosage=DosageBuilder.build(
            dose_value=1,
            dose_unit="tablet",
            frequency=3,
            period=1,
            period_unit="d",
            route=RouteOfAdministration.ORAL,
            timing_code=EventTiming.AFTER_MEAL,
            text="Take 1 tablet three times daily after meals"
        )).json()
# Out:
# '{"resourceType":"MedicationRequest","id":"27adc78f-40f1-43b9-aaea-6e30a1d55e8a","status":"active","intent":"order","medication":{"concept":{"text":"Dolo 650 Tablet"}},"dosageInstruction":[{"text":"Take 1 tablet three times daily after meals","timing":{"repeat":{"frequency":3,"period":1.0,"periodUnit":"d","when":["PC"]}},"asNeeded":false,"route":{"coding":[{"system":"http://snomed.info/sct","code":"26643006","display":"Oral"}],"text":"Oral"},"doseAndRate":[{"doseQuantity":{"value":1.0,"unit":"tablet","system":"http://unitsofmeasure.org","code":"tablet"}}]}]}'
